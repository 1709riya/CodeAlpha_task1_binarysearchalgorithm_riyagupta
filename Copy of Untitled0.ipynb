# %%
def generate_binary_range(start, end):
    current = start
    while current <= end:
        yield bin(current)[2:]
        current += 2

start = 0
end = 16

for binary_number in generate_binary_range(start, end):
    print(binary_number)
# Out:
# 0
# 10
# 100
# 110
# 1000
# 1010
# 1100
# 1110
# 10000
